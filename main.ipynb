# %%
import time
import pickle
import gensim
from gensim.models import Word2Vec, KeyedVectors

from utils import get

# %%
data=[]
for i in range(1, get()+1):
    with open (f'data1/chunk_{i}.pickle','rb') as file:
        data+=pickle.load(file)

    data=[i for i in data if len(i) > 0]
print(f'Найдено {len(data)} не пустых предложений')
# Out:
# Найдено 5764 не пустых предложений

# %%
start_time=time.time()

model=Word2Vec(sentences=data, 
               sg=1,
               vector_size=100,
               workers=8)

print(f'Время заняло:{(time.time() - start_time) /60:.2f}mins')
# Out:
# Время заняло:0.01mins

# %%
model.wv.most_similar('нога')

model.wv.save_word2vec_format('custom_embedding.txt')

w2v=KeyedVectors.load_word2vec_format('custom_embedding.txt')

w2v.similarity('нога','рука')

def get_most(word,topn):
    vals=model.wv.most_similar(word,topn=topn)
    d={k: i + 2 for i, (k,v) in enumerate(vals)}
    return d
get_most('нога', 10000)
# Out:
# {'поезд': 2,
#  'доставлять': 3,
#  'производитель': 4,
#  'оборудование': 5,
#  'метод': 6,
#  'пытаться': 7,
#  'угроза': 8,
#  'обеспечивать': 9,
#  'июль': 10,
#  'вести': 11,
#  'игра': 12,
#  'язык': 13,
#  'обратный': 14,
#  'боец': 15,
#  'оружие': 16,
#  'праздничный': 17,
#  'престол': 18,
#  'акционер': 19,
#  'соответствующий': 20,
#  'офис': 21,
#  'японский': 22,
#  'спрашивать': 23,
#  'модернизация': 24,
#  'роль': 25,
#  'неделя': 26,
#  'сантиметр': 27,
#  'купить': 28,
#  'больший': 29,
#  'отчет': 30,
#  'нападающий': 31,
#  'электронный': 32,
#  'поставлять': 33,
#  'снижение': 34,
#  'удалять': 35,
#  'экипаж': 36,
#  'продукция': 37,
#  'инвестор': 38,
#  'ресторан': 39,
#  'минута': 40,
#  'округ': 41,
#  'технический': 42,
#  'работник': 43,
#  'канал': 44,
#  'спорт': 45,
#  'важный': 46,
#  'огромный': 47,
#  'мозг': 48,
#  'личный': 49,
#  'соглашаться': 50,
#  'дверь': 51,
#  'инфраструктура': 52,
#  'понести': 53,
#  'покидать': 54,
#  'политический': 55,
#  'сериал': 56,
#  'небольшой': 57,
#  'храм': 58,
#  'необходимость': 59,
#  'нарушать': 60,
#  'клетка': 61,
#  'атаковать': 62,
#  'сфера': 63,
#  'заменять': 64,
#  'приносить': 65,
#  'пойти': 66,
#  'конституция': 67,
#  'подготовить': 68,
#  'ликвидировать': 69,
#  'приезжать': 70,
#  'следователь': 71,
#  'отечественный': 72,
#  'замечание': 73,
#  'угрожать': 74,
#  'пища': 75,
#  'движение': 76,
#  'будущее': 77,
#  'стадион': 78,
#  'установка': 79,
#  'искать': 80,
#  'спартак': 81,
#  'лес': 82,
#  'определять': 83,
#  'законопроект': 84,
#  'рука': 85,
#  'акт': 86,
#  'борьба': 87,
#  'встречать': 88,
#  'влияние': 89,
#  'модель': 90,
#  'возглавлять': 91,
#  'конкурс': 92,
#  'судно': 93,
#  'запись': 94,
#  'рожать': 95,
#  'домашний': 96,
#  'располагать': 97,
#  'вид': 98,
#  'собака': 99,
#  'делегация': 100,
#  'родственник': 101,
#  'протест': 102,
#  'надежда': 103,
#  'кадыров': 104,
#  'убивать': 105,
#  'распространенный': 106,
#  'выполнение': 107,
#  'пытка': 108,
#  'герой': 109,
#  'складываться': 110,
#  'долг': 111,
#  'росгвардия': 112,
#  'подмосковный': 113,
#  'посвящать': 114,
#  'лицо': 115,
#  'выполнять': 116,
#  'алкогольный': 117,
#  'поправка': 118,
#  'ядерный': 119,
#  'собрание': 120,
#  'цвет': 121,
#  'способный': 122,
#  'водитель': 123,
#  'денис': 124,
#  'путь': 125,
#  'основание': 126,
#  'артист': 127,
#  'положительный': 128,
#  'семейный': 129,
#  'поколение': 130,
#  'остров': 131,
#  'пациент': 132,
#  'ограничение': 133,
#  'развивать': 134,
#  'признак': 135,
#  'труба': 136,
#  'показание': 137,
#  'военнослужащий': 138,
#  'кевин': 139,
#  'машина': 140,
#  'опасный': 141,
#  'боевик': 142,
#  'план': 143,
#  'фото': 144,
#  'точка': 145,
#  'игрок': 146,
#  'образец': 147,
#  'связывать': 148,
#  'одобрять': 149,
#  'означать': 150,
#  'мобильный': 151,
#  'посадка': 152,
#  'долгий': 153,
#  'разрешать': 154,
#  'сенатор': 155,
#  'заключать': 156,
#  'заключение': 157,
#  'атака': 158,
#  'бой': 159,
#  'пропадать': 160,
#  'учреждение': 161,
#  'турнир': 162,
#  'увольнять': 163,
#  'проверка': 164,
#  'хозяин': 165,
#  'крыша': 166,
#  'чемодан': 167,
#  'запрос': 168,
#  'посетитель': 169,
#  'свидетельствовать': 170,
#  'мокнуть': 171,
#  'организатор': 172,
#  'страж': 173,
#  'еда': 174,
#  'площадка': 175,
#  'наблюдаться': 176,
#  'совершать': 177,
#  'применять': 178,
#  'запуск': 179,
#  'улица': 180,
#  'признаваться': 181,
#  'дочь': 182,
#  'актер': 183,
#  'клиент': 184,
#  'аэрофлот': 185,
#  'эффективность': 186,
#  'кокорин': 187,
#  'запускать': 188,
#  'грудь': 189,
#  'разрабатывать': 190,
#  'уфимский': 191,
#  'вэйд': 192,
#  'музыкант': 193,
#  'отделение': 194,
#  'девочка': 195,
#  'выясняться': 196,
#  'лечение': 197,
#  'река': 198,
#  'золотой': 199,
#  'мигрант': 200,
#  'резкий': 201,
#  'спортивный': 202,
#  'комментарий': 203,
#  'космический': 204,
#  'священник': 205,
#  'провожать': 206,
#  'популярный': 207,
#  'газета': 208,
#  'проводиться': 209,
#  'нападать': 210,
#  'комментировать': 211,
#  'космодром': 212,
#  'повышать': 213,
#  'проигрывать': 214,
#  'ученый': 215,
#  'константин': 216,
#  'французский': 217,
#  'свидетельство': 218,
#  'отправлять': 219,
#  'реакция': 220,
#  'покупать': 221,
#  'реформа': 222,
#  'мертвый': 223,
#  'подарок': 224,
#  'обыск': 225,
#  'пользоваться': 226,
#  'круглый': 227,
#  'сервис': 228,
#  'капитан': 229,
#  'активный': 230,
#  'воробей': 231,
#  'возникать': 232,
#  'подходить': 233,
#  'захват': 234,
#  'подготовка': 235,
#  'ошибка': 236,
#  'полный': 237,
#  'одежда': 238,
#  'предмет': 239,
#  'узнавать': 240,
#  'предприниматель': 241,
#  'блогер': 242,
#  'взаимодействие': 243,
#  'спонсор': 244,
#  'климов': 245,
#  'отдельный': 246,
#  'попытка': 247,
#  'факт': 248,
#  'привлекательный': 249,
#  'подводить': 250,
#  'заниматься': 251,
#  'специалист': 252,
#  'происшествие': 253,
#  'перенести': 254,
#  'якубов': 255,
#  'напиток': 256,
#  'забивать': 257,
#  'вещь': 258,
#  'финал': 259,
#  'митинг': 260,
#  'певица': 261,
#  'гвинея': 262,
#  'карьера': 263,
#  'собственный': 264,
#  'запад': 265,
#  'обсуждение': 266,
#  'олег': 267,
#  'хакер': 268,
#  'саммит': 269,
#  'конституционный': 270,
#  'хет-трик': 271,
#  'минский': 272,
#  'всемирный': 273,
#  'подразделение': 274,
#  'открывать': 275,
#  'чечня': 276,
#  'смотреть': 277,
#  'париж': 278,
#  'секс': 279,
#  'команда': 280,
#  'голова': 281,
#  'жительница': 282,
#  'специальный': 283,
#  'комиссия': 284,
#  'доступ': 285,
#  'сдавать': 286,
#  'продукт': 287,
#  'переставать': 288,
#  'предотвращать': 289,
#  'банда': 290,
#  'событие': 291,
#  'плей-офф': 292,
#  'депутат': 293,
#  'исполнитель': 294,
#  'сказываться': 295,
#  'выдавать': 296,
#  'подтверждать': 297,
#  'учащийся': 298,
#  'армения': 299,
#  'пункт': 300,
#  'оказание': 301,
#  'костюм': 302,
#  'договоренность': 303,
#  'драма': 304,
#  'шайба': 305,
#  'формирование': 306,
#  'холодный': 307,
#  'ассоциация': 308,
#  'задержание': 309,
#  'потребоваться': 310,
#  'удаваться': 311,
#  'процедура': 312,
#  'разрешение': 313,
#  'отсутствие': 314,
#  'приговаривать': 315,
#  'выражать': 316,
#  'топливо': 317,
#  'юрий': 318,
#  'гость': 319,
#  'студия': 320,
#  'сердце': 321,
#  'личность': 322,
#  'ролик': 323,
#  'армия': 324,
#  'употребление': 325,
#  'индивидуальный': 326,
#  'цска': 327,
#  'общество': 328,
#  'отверстие': 329,
#  'скрываться': 330,
#  'частный': 331,
#  'намерен': 332,
#  'тяжелый': 333,
#  'чемпион': 334,
#  'клуб': 335,
#  'ингушетия': 336,
#  'прокуратура': 337,
#  'госпитализировать': 338,
#  'сексуальный': 339,
#  'регулярный': 340,
#  'механизм': 341,
#  'взять': 342,
#  'искусственный': 343,
#  'олимпийский': 344,
#  'журнал': 345,
#  'отвергать': 346,
#  'способствовать': 347,
#  'ключ': 348,
#  'академия': 349,
#  'массовый': 350,
#  'сбивать': 351,
#  'телефон': 352,
#  'животное': 353,
#  'плата': 354,
#  'огонь': 355,
#  'сохранять': 356,
#  'поселок': 357,
#  'нож': 358,
#  'должность': 359,
#  'восстанавливать': 360,
#  'расследование': 361,
#  'повод': 362,
#  'играть': 363,
#  'медицинский': 364,
#  'помогать': 365,
#  'родитель': 366,
#  'компетенция': 367,
#  'пак': 368,
#  'дорога': 369,
#  'соцсеть': 370,
#  'сизо': 371,
#  'оказывать': 372,
#  'отреагировать': 373,
#  'финансовый': 374,
#  'эфир': 375,
#  'билет': 376,
#  'пройти': 377,
#  'привлекать': 378,
#  'лейтенант': 379,
#  'пояснять': 380,
#  'объединение': 381,
#  'свердловский': 382,
#  'торговый': 383,
#  'желание': 384,
#  'построить': 385,
#  'действующий': 386,
#  'десяток': 387,
#  'законодательство': 388,
#  'болезнь': 389,
#  'заявка': 390,
#  'версия': 391,
#  'западный': 392,
#  'поделиться': 393,
#  'агрессор': 394,
#  'подозреваемый': 395,
#  'раскритиковывать': 396,
#  'рубеж': 397,
#  'закрывать': 398,
#  'й': 399,
#  'сокращение': 400,
#  'удар': 401,
#  'рэпер': 402,
#  'вынуждать': 403,
#  'письмо': 404,
#  'тест': 405,
#  'видеозапись': 406,
#  'проживать': 407,
#  'налоговый': 408,
#  'возможный': 409,
#  'переходить': 410,
#  'бразильский': 411,
#  'минобороны': 412,
#  'атмосфера': 413,
#  'обычный': 414,
#  'выводить': 415,
#  'кофе': 416,
#  'стратегический': 417,
#  'участок': 418,
#  'поражение': 419,
#  'исследователь': 420,
#  'сыграть': 421,
#  'войско': 422,
#  'умирать': 423,
#  'вещество': 424,
#  'промышленность': 425,
#  'садиться': 426,
#  'аппарат': 427,
#  'полагать': 428,
#  'топ': 429,
#  'рамка': 430,
#  'усиливать': 431,
#  'отказывать': 432,
#  'районный': 433,
#  'полномочие': 434,
#  'называться': 435,
#  'эвакуировать': 436,
#  'китайский': 437,
#  'дознавательница': 438,
#  'дисквалификация': 439,
#  'боксер': 440,
#  'продолжать': 441,
#  'переговоры': 442,
#  'запрашивать': 443,
#  'обвиняемый': 444,
#  'профессия': 445,
#  'способ': 446,
#  'донбасс': 447,
#  'идея': 448,
#  'стол': 449,
#  'преступник': 450,
#  'наличие': 451,
#  'колония': 452,
#  'ракетный': 453,
#  'рассматривать': 454,
#  'давление': 455,
#  'остановка': 456,
#  'тариф': 457,
#  'судебный': 458,
#  'индия': 459,
#  'туроператор': 460,
#  'тело': 461,
#  'устраивать': 462,
#  'будущий': 463,
#  'размещать': 464,
#  'доктор': 465,
#  'бог': 466,
#  'партнер': 467,
#  'вывод': 468,
#  'ремонт': 469,
#  'состояние': 470,
#  'виновный': 471,
#  'энергетика': 472,
#  'индийский': 473,
#  'пол': 474,
#  'фотография': 475,
#  'продлять': 476,
#  'производство': 477,
#  'загородный': 478,
#  'чеченский': 479,
#  'введение': 480,
#  'одкб': 481,
#  'пора': 482,
#  'мера': 483,
#  'земля': 484,
#  'максим': 485,
#  'останавливать': 486,
#  'попытаться': 487,
#  'рождество': 488,
#  'приложение': 489,
#  'показывать': 490,
#  'фермер': 491,
#  'независимость': 492,
#  'демократический': 493,
#  'минздрав': 494,
#  'зависеть': 495,
#  'федерация': 496,
#  'экстренный': 497,
#  'проектория': 498,
#  'бензин': 499,
#  'наука': 500,
#  'успех': 501,
#  'институт': 502,
#  'сочи': 503,
#  'режим': 504,
#  'мирный': 505,
#  'дерипаска': 506,
#  'дефицит': 507,
#  'операция': 508,
#  'транспорт': 509,
#  'адрес': 510,
#  'традиционный': 511,
#  'прогноз': 512,
#  'профессиональный': 513,
#  'штаб': 514,
#  'запас': 515,
#  'рождественский': 516,
#  'злоумышленник': 517,
#  'совершение': 518,
#  'обязанность': 519,
#  'эбола': 520,
#  'избивать': 521,
#  'епархия': 522,
#  'апрель': 523,
#  'паспорт': 524,
#  'следующий': 525,
#  'силовой': 526,
#  'зал': 527,
#  'ограничивать': 528,
#  'руководство': 529,
#  'снег': 530,
#  'качество': 531,
#  'прокурор': 532,
#  'испытание': 533,
#  'подписчик': 534,
#  'насилие': 535,
#  'бросать': 536,
#  'изменять': 537,
#  'приговор': 538,
#  'заболевание': 539,
#  'особый': 540,
#  'протоиерей': 541,
#  'шаг': 542,
#  'прокопьев': 543,
#  'зенит': 544,
#  'сумка': 545,
#  'объединяться': 546,
#  'отбирать': 547,
#  'технология': 548,
#  'драка': 549,
#  'связанный': 550,
#  'предназначать': 551,
#  'разрушать': 552,
#  'середина': 553,
#  'сми': 554,
#  'проголосовать': 555,
#  'ольга': 556,
#  'поставка': 557,
#  'вооружение': 558,
#  'содержание': 559,
#  'сильный': 560,
#  'думать': 561,
#  'обещать': 562,
#  'сеть': 563,
#  'крым': 564,
#  'россеть': 565,
#  'боль': 566,
#  'университет': 567,
#  'марка': 568,
#  'очередь': 569,
#  'иметься': 570,
#  'х': 571,
#  'плохой': 572,
#  'смена': 573,
#  'исполнять': 574,
#  'тейф': 575,
#  'суметь': 576,
#  'проверять': 577,
#  'направлять': 578,
#  'кабинет': 579,
#  'пример': 580,
#  'отправляться': 581,
#  'дипломат': 582,
#  'цб': 583,
#  'соответствовать': 584,
#  'ответ': 585,
#  'лужники': 586,
#  'готовность': 587,
#  'английский': 588,
#  'сидеть': 589,
#  'случаться': 590,
#  'южный': 591,
#  'заинтересовывать': 592,
#  'незаконный': 593,
#  'наступление': 594,
#  'советский': 595,
#  'род': 596,
#  'тюрьма': 597,
#  'нехватка': 598,
#  'май': 599,
#  'ключевой': 600,
#  'парламент': 601,
#  'протяжение': 602,
#  'ожидать': 603,
#  'рабочий': 604,
#  'волос': 605,
#  'маневр': 606,
#  'фрагмент': 607,
#  'боевой': 608,
#  'баскак': 609,
#  'белый': 610,
#  'ум': 611,
#  'брать': 612,
#  'инициатива': 613,
#  'фильм': 614,
#  'скандал': 615,
#  'отец': 616,
#  'американец': 617,
#  'немецкий': 618,
#  'блок': 619,
#  'европа': 620,
#  'урегулирование': 621,
#  'останавливаться': 622,
#  'начинаться': 623,
#  'большинство': 624,
#  'зарубежный': 625,
#  'интернет': 626,
#  'недовольство': 627,
#  'мировой': 628,
#  'надеяться': 629,
#  'воспользоваться': 630,
#  'научный': 631,
#  'добираться': 632,
#  'осуждать': 633,
#  'хакерский': 634,
#  'вечеринка': 635,
#  'чувствовать': 636,
#  'википедия': 637,
#  'внешний': 638,
#  'ежегодный': 639,
#  'устройство': 640,
#  'футболист': 641,
#  'выявлять': 642,
#  'немой': 643,
#  'документ': 644,
#  'простой': 645,
#  'дополнительный': 646,
#  'вернуться': 647,
#  'налог': 648,
#  'относиться': 649,
#  'комплекс': 650,
#  'рак': 651,
#  'забывать': 652,
#  'возвращение': 653,
#  'утечка': 654,
#  'попросить': 655,
#  'следовать': 656,
#  'игорь': 657,
#  'улучшать': 658,
#  'страсбург': 659,
#  'доказывать': 660,
#  'столичный': 661,
#  'цыпленок': 662,
#  'посмотреть': 663,
#  'исполнение': 664,
#  'допускать': 665,
#  'стража': 666,
#  'взлет': 667,
#  'прямой': 668,
#  'кровь': 669,
#  'космос': 670,
#  'мясо': 671,
#  'позволять': 672,
#  'восстановление': 673,
#  'присутствие': 674,
#  'открытие': 675,
#  'правонарушение': 676,
#  'сирия': 677,
#  'региональный': 678,
#  'центральный': 679,
#  'муж': 680,
#  'оскорбление': 681,
#  'кодекс': 682,
#  'темп': 683,
#  'единственный': 684,
#  'пилот': 685,
#  'футбольный': 686,
#  'глацкий': 687,
#  'вода': 688,
#  'вылетать': 689,
#  'кампания': 690,
#  'увидеть': 691,
#  'ранить': 692,
#  'вино': 693,
#  'агент': 694,
#  'канада': 695,
#  'использование': 696,
#  'заподозривать': 697,
#  'поле': 698,
#  'состоять': 699,
#  'часы': 700,
#  'различный': 701,
#  'масса': 702,
#  'ходить': 703,
#  'екатеринбург': 704,
#  'британский': 705,
#  'франция': 706,
#  'поиск': 707,
#  'здоровье': 708,
#  'сторонник': 709,
#  'указание': 710,
#  'япония': 711,
#  'вагон': 712,
#  'оливье': 713,
#  'брюссель': 714,
#  'яндекс': 715,
#  'конашенков': 716,
#  'чиновница': 717,
#  'аршавин': 718,
#  'сделать': 719,
#  'сотрудничество': 720,
#  'арестовывать': 721,
#  'медаль': 722,
#  'следить': 723,
#  'акция': 724,
#  'предоставлять': 725,
#  'спецслужба': 726,
#  'германия': 727,
#  'защита': 728,
#  'восточный': 729,
#  'сбербанк': 730,
#  'подозревать': 731,
#  'готовить': 732,
#  'народ': 733,
#  'телевидение': 734,
#  'известный': 735,
#  'подсчитывать': 736,
#  'реализация': 737,
#  'содержать': 738,
#  'исторический': 739,
#  'доступный': 740,
#  'псковский': 741,
#  'выборы': 742,
#  'ученик': 743,
#  'количество': 744,
#  'защищать': 745,
#  'распространение': 746,
#  'бутик': 747,
#  'поединок': 748,
#  'запрет': 749,
#  'модернизировать': 750,
#  'живой': 751,
#  'основа': 752,
#  'служебный': 753,
#  'борт': 754,
#  'смысл': 755,
#  'кононенко': 756,
#  'сухой': 757,
#  'австралия': 758,
#  'парламентарий': 759,
#  'вооруженный': 760,
#  'определяться': 761,
#  'финансирование': 762,
#  'кислород': 763,
#  'хозяйство': 764,
#  'отдых': 765,
#  'монсон': 766,
#  'модный': 767,
#  'эффективный': 768,
#  'люксовый': 769,
#  'завершать': 770,
#  'выяснять': 771,
#  'косово': 772,
#  'африка': 773,
#  'понятие': 774,
#  'внутренний': 775,
#  'операционный': 776,
#  'образовательный': 777,
#  'ранение': 778,
#  'линия': 779,
#  'черный': 780,
#  'транспортный': 781,
#  'предприятие': 782,
#  'подход': 783,
#  'персонаж': 784,
#  'корея': 785,
#  'объяснять': 786,
#  'завод': 787,
#  'смерть': 788,
#  'подвал': 789,
#  'победитель': 790,
#  'пострадавший': 791,
#  'мадридский': 792,
#  'окно': 793,
#  'удерживать': 794,
#  'коллекция': 795,
#  'существовать': 796,
#  'шоу': 797,
#  'месторождение': 798,
#  'нападение': 799,
#  'испанский': 800,
#  'наказывать': 801,
#  'зона': 802,
#  'труд': 803,
#  'разработка': 804,
#  'разный': 805,
#  'предварительный': 806,
#  'супруга': 807,
#  'тверской': 808,
#  'болюс': 809,
#  'желтый': 810,
#  'скорый': 811,
#  'критика': 812,
#  'зачитывать': 813,
#  'павел': 814,
#  'чиновник': 815,
#  'сделка': 816,
#  'робот': 817,
#  'необходимый': 818,
#  'совместный': 819,
#  'особняк': 820,
#  'магазин': 821,
#  'востребовать': 822,
#  'краснодар': 823,
#  'правовой': 824,
#  'идти': 825,
#  'след': 826,
#  'террорист': 827,
#  'проведение': 828,
#  'неизвестный': 829,
#  'взятка': 830,
#  'отличие': 831,
#  'длительный': 832,
#  'воздушный': 833,
#  'консервативный': 834,
#  'молодой': 835,
#  'заставлять': 836,
#  'визит': 837,
#  'носить': 838,
#  'добиваться': 839,
#  'климат': 840,
#  'отрасль': 841,
#  'поймать': 842,
#  'пассажир': 843,
#  'задача': 844,
#  'назначать': 845,
#  'близкий': 846,
#  'арсенал': 847,
#  'утро': 848,
#  'побеждать': 849,
#  'соглашение': 850,
#  'кибербезопасность': 851,
#  'принадлежать': 852,
#  'маска': 853,
#  'препарат': 854,
#  'предусматривать': 855,
#  'условие': 856,
#  'уничтожать': 857,
#  'камера': 858,
#  'договариваться': 859,
#  'быдло': 860,
#  'концерт': 861,
#  'управлять': 862,
#  'фас': 863,
#  'старый': 864,
#  'пассажирский': 865,
#  'сцена': 866,
#  'переход': 867,
#  'зритель': 868,
#  'предполагать': 869,
#  'наказание': 870,
#  'процесс': 871,
#  'ярмарка': 872,
#  'вероятный': 873,
#  'вечный': 874,
#  'полет': 875,
#  'ирина': 876,
#  'мотив': 877,
#  'прибывать': 878,
#  'винчестер': 879,
#  'шериф': 880,
#  'расти': 881,
#  'лежать': 882,
#  'интерес': 883,
#  'дисциплинарный': 884,
#  'итальянский': 885,
#  'донецкий': 886,
#  'похищение': 887,
#  'поставщик': 888,
#  'брюс': 889,
#  'ленинград': 890,
#  'номер': 891,
#  'платежный': 892,
#  'просить': 893,
#  'регулятор': 894,
#  'учебный': 895,
#  'проявлять': 896,
#  'замечать': 897,
#  'активист': 898,
#  'ходатайство': 899,
#  'учебник': 900,
#  'пожарный': 901,
#  'шипулин': 902,
#  'сталкиваться': 903,
#  'символ': 904,
#  'сходить': 905,
#  'пекин': 906,
#  'приют': 907,
#  'налагать': 908,
#  'бутина': 909,
#  'елена': 910,
#  'рф': 911,
#  'нынешний': 912,
#  'пожаловаться': 913,
#  'поисковый': 914,
#  'выпуск': 915,
#  'прохожий': 916,
#  'реклама': 917,
#  'побои': 918,
#  'включать': 919,
#  'вернуть': 920,
#  'каспэнергосбыт': 921,
#  'основной': 922,
#  'коллектив': 923,
#  'кинжал': 924,
#  'ответственность': 925,
#  'приземляться': 926,
#  'файл': 927,
#  'прибыль': 928,
#  'предложение': 929,
#  'рождение': 930,
#  'производить': 931,
#  'мошенничество': 932,
#  'республиканский': 933,
#  'вице-губернатор': 934,
#  'подобный': 935,
#  'воспитанник': 936,
#  'посещать': 937,
#  'откладывать': 938,
#  'доверие': 939,
#  'должностной': 940,
#  'серьезный': 941,
#  'духовенство': 942,
#  'обязывать': 943,
#  'организовывать': 944,
#  'головной': 945,
#  'реал': 946,
#  'святой': 947,
#  'видеть': 948,
#  'выпускать': 949,
#  'малый': 950,
#  'вставать': 951,
#  'ведущий': 952,
#  'применение': 953,
#  'счетный': 954,
#  'необоснованный': 955,
#  'автор': 956,
#  'постанавливать': 957,
#  'председатель': 958,
#  'свитер': 959,
#  'знакомый': 960,
#  'великобритания': 961,
#  'продолжаться': 962,
#  'гарнитур': 963,
#  'лишать': 964,
#  'превышение': 965,
#  'урок': 966,
#  'медведев': 967,
#  'приходиться': 968,
#  'вертолет': 969,
#  'спутник': 970,
#  'восток': 971,
#  'обязательный': 972,
#  'оснащать': 973,
#  'дорожный': 974,
#  'мэрия': 975,
#  'смартфон': 976,
#  'кризис': 977,
#  'заказ': 978,
#  'барселона': 979,
#  'игрушка': 980,
#  'водоснабжение': 981,
#  'мост': 982,
#  'ужасный': 983,
#  'пограничный': 984,
#  'пересекать': 985,
#  'тренд': 986,
#  'исследование': 987,
#  'подвергаться': 988,
#  'пенсионер': 989,
#  'учение': 990,
#  'зобнина': 991,
#  'певец': 992,
#  'настаивать': 993,
#  'степень': 994,
#  'получение': 995,
#  'череп': 996,
#  'минск': 997,
#  'статус': 998,
#  'голосование': 999,
#  'бороться': 1000,
#  'нхл': 1001,
#  ...}

# %%
import gensim.downloader as api

# %%
model=api.load('word2vec-ruscorpora-300')

list(model.key_to_index.items())[:10]
d={k.split('_')[0]: k  for k in model.key_to_index}
model.similarity(d['нога'],d['рука'])
# Out:
# 0.539018

# %%
def get_most(word,topn):
    vals=model.most_similar(d[word],topn=topn)
    d_={k.split('_')[0]: i + 2 for i, (k,v) in enumerate(vals)}
    return d_
get_most('нога', 10000)
# Out:
# {'ступня': 2,
#  'колено': 3,
#  'пятка': 4,
#  'коленка': 5,
#  'ножище': 6,
#  'щиколотка': 7,
#  'босой': 8,
#  'ножка': 9,
#  'выбленка': 10,
#  'подгибать': 11,
#  'голень': 12,
#  'подгибаться': 13,
#  'лапшиних': 14,
#  'шмурыгивать': 15,
#  'лодыжка': 16,
#  'бедро': 17,
#  'спина': 18,
#  'сгибать': 19,
#  'туловище': 20,
#  'перехватиться': 21,
#  'локоть': 22,
#  'ножонка': 23,
#  'чикилять': 24,
#  'отерпнуть': 25,
#  'ляпнуться': 26,
#  'подрыгать': 27,
#  'необутый': 28,
#  'подворачивать': 29,
#  'подсечься': 30,
#  'поприседать': 31,
#  'носок': 32,
#  'лапа': 33,
#  'обстрекаться': 34,
#  'осклизаться': 35,
#  'по-лягушачьи': 36,
#  'сапог': 37,
#  'коленный::чашечка': 38,
#  'сгибаться': 39,
#  'каблук': 40,
#  'дрыгать': 41,
#  'обхватить': 42,
#  'шея': 43,
#  'замахнуть': 44,
#  'ляжка': 45,
#  'надернуть': 46,
#  'щиколка': 47,
#  'волочить': 48,
#  'полуприседать': 49,
#  'лапка': 50,
#  'потопывать': 51,
#  'заторский': 52,
#  'олочь': 53,
#  'башмак': 54,
#  'отлягиваться': 55,
#  'рученка': 56,
#  'угнуть': 57,
#  'живот': 58,
#  'тряхнуться': 59,
#  'одубеть': 60,
#  'кручь': 61,
#  'зацепенеть': 62,
#  'копыто': 63,
#  'полусогнутый': 64,
#  'дручок': 65,
#  'ботинок': 66,
#  'подкашиваться': 67,
#  'враскоряка': 68,
#  'поясница': 69,
#  'броском': 70,
#  'спружинивать': 71,
#  'калошка': 72,
#  'спотыкаться': 73,
#  'костыль': 74,
#  'слань': 75,
#  'по-клоунски': 76,
#  'раскорячка': 77,
#  'штанина': 78,
#  'подволакивать': 79,
#  'допятиться': 80,
#  'мослаковатый': 81,
#  'четвереньки': 82,
#  'вразмашку': 83,
#  'повалиться': 84,
#  'хрястать': 85,
#  'стаптывать': 86,
#  'туфля': 87,
#  'подпрыгивать': 88,
#  'неслушаться': 89,
#  'прострелить::навылет': 90,
#  'каблучища': 91,
#  'угнуться': 92,
#  'надькин': 3924,
#  'голеностопный::сустав': 94,
#  'брючина': 95,
#  'прихрамывать': 96,
#  'взлягивать': 97,
#  'рука': 98,
#  'вытягивать': 99,
#  'ничком': 100,
#  'затекать': 101,
#  'полозить': 102,
#  'разгибаться': 103,
#  'подковылять': 104,
#  'отброситься': 105,
#  'бутсы': 106,
#  'брыкнуться': 107,
#  'плюсна': 108,
#  'подламываться': 109,
#  'навзничь': 110,
#  'корячка': 111,
#  'подтесывать': 112,
#  'палка': 113,
#  'негнуться': 114,
#  'поламывать': 115,
#  'отдавливать': 116,
#  'расстегивать::ширинка': 117,
#  'оттаптывать': 118,
#  'пимный': 119,
#  'ножища': 120,
#  'палец': 121,
#  'атропка': 122,
#  'сподники': 123,
#  'разуваться': 124,
#  'согнутый': 125,
#  'полусидячий': 126,
#  'растопыривать': 127,
#  'приосеть': 128,
#  'валеркина': 129,
#  'свешивать': 130,
#  'шмурыгать': 131,
#  'задрыгать': 132,
#  'затекший': 133,
#  'обожжение': 134,
#  'клешнятый': 135,
#  'взнимать': 136,
#  'шустенок': 137,
#  'подтыкаться': 138,
#  'брыкать': 139,
#  'опорок': 140,
#  'пах': 141,
#  'придерживать': 142,
#  'бок': 143,
#  'рубаха::распояска': 144,
#  'кусаться::царапаться': 145,
#  'грохнуться::оземь': 146,
#  'скрючивать': 147,
#  'запинать': 148,
#  'пральник': 149,
#  'лунатически': 150,
#  'деревяга': 151,
#  'ступенечек': 152,
#  'ковылять': 153,
#  'дерг::дерг': 154,
#  'нагинаться': 155,
#  'подог': 156,
#  'врастопырку': 157,
#  'огрызов': 158,
#  'стоптать': 159,
#  'запаленно': 160,
#  'плашмя': 161,
#  'грудь': 162,
#  'подошва': 163,
#  'нагибаться': 164,
#  'тпрукать': 165,
#  'пошаркивать': 166,
#  'рассупонивать': 167,
#  'култыхать': 168,
#  'брюхо': 169,
#  'отвалиться': 170,
#  'вьетнамки': 171,
#  'пан::бартломей': 172,
#  'притопывать': 173,
#  'фридка': 174,
#  'рукоед': 175,
#  'полусогнуться': 176,
#  'генка::шамай': 177,
#  'гуслинский': 178,
#  'ляский': 179,
#  'несгибаться': 180,
#  'пинаться': 181,
#  'ступать': 182,
#  'култышка': 183,
#  'затылок': 184,
#  'брякаться': 185,
#  'подколенок': 186,
#  'валеркин::мамка': 187,
#  'взмотнуть': 188,
#  'прохошка': 189,
#  'оскальзываться': 190,
#  'улядь': 191,
#  'пузырить': 192,
#  'блесткий': 193,
#  'пригибать': 194,
#  'оскользаться': 195,
#  'обувать': 196,
#  'лопашный': 197,
#  'закинуть': 198,
#  'сустав': 199,
#  'коленочка': 200,
#  'кубарем::скатываться': 201,
#  'эроплан': 202,
#  'грузно': 203,
#  'прибинтовывать': 204,
#  'рухать': 205,
#  'педать': 206,
#  'хруп': 1000,
#  'угребаться': 208,
#  'отекать': 209,
#  'тычком': 210,
#  'ладонь': 211,
#  'косолапить': 212,
#  'конечность': 213,
#  'зубище': 214,
#  'дрыгнуть': 215,
#  'пегаш': 216,
#  'посучить': 217,
#  'полуоборотиться': 218,
#  'расставить': 219,
#  'сапожище': 220,
#  'стоптаться': 221,
#  'катнуться': 222,
#  'туфелька': 223,
#  'хильдегунда': 224,
#  'ноженька': 225,
#  'похромать': 226,
#  'подрушник': 227,
#  'шкутенок': 228,
#  'примост': 229,
#  'извозить': 230,
#  'полулеглый': 231,
#  'кувырнуться': 232,
#  'изработанный': 233,
#  'грядушка': 234,
#  'шаркать': 235,
#  'расшнуровывать::ботинок': 236,
#  'некованый': 237,
#  'залубенеть': 238,
#  'схлестнуть': 239,
#  'закорючивать': 240,
#  'распухать': 241,
#  'штан': 242,
#  'микишар': 243,
#  'выбивалка': 244,
#  'путях': 245,
#  'спотыкнуться': 246,
#  'чапиг': 247,
#  'одервенеть': 248,
#  'босиком': 249,
#  'юфтовой': 250,
#  'выпрямляться': 251,
#  'скорчиться': 252,
#  'задирать': 253,
#  'стяжок': 254,
#  'нагибать': 255,
#  'бродень': 256,
#  'чурбанчик': 257,
#  'раскорячивать': 258,
#  'монументик': 259,
#  'плечо': 260,
#  'потряхиваться': 261,
#  'грохнуться': 262,
#  'загрозиться': 263,
#  'ссовывать': 264,
#  'товаришш': 265,
#  'пнуть': 266,
#  'полупальце': 267,
#  'сойманов': 268,
#  'валеркина::мамка': 269,
#  'переступь': 270,
#  'разможженный': 271,
#  'поджинать': 272,
#  'онемевать': 273,
#  'крючиться': 274,
#  'сандалия': 275,
#  'зудиться': 276,
#  'щепать::лучина': 277,
#  'гакнуть': 278,
#  'мокрехонький': 279,
#  'егорко': 280,
#  'остропера': 281,
#  'приседать': 282,
#  'камуфляжник': 283,
#  'нерасседлывать': 284,
#  'пересмякать': 285,
#  'заслонясь': 286,
#  'полубокий': 287,
#  'грянуться::оземь': 288,
#  'неуклюже': 289,
#  'подземник': 290,
#  'пружинить': 291,
#  'зашатать': 292,
#  'дзерия': 293,
#  'насруллаев': 294,
#  'валежин': 295,
#  'дубравкин': 296,
#  'валибед': 297,
#  'выпрямиться': 298,
#  'прискок': 299,
#  'взбудораженно': 300,
#  'засандаливать': 301,
#  'иргашев': 302,
#  'оттопывать': 303,
#  'эть': 304,
#  'газеев': 305,
#  'удушиться': 306,
#  'дубасей': 307,
#  'напружинивать': 308,
#  'кокнуться': 309,
#  'ширявый': 310,
#  'подшаркивать': 311,
#  'ремень': 312,
#  'припрыгивать': 313,
#  'медвеженка': 314,
#  'отжевывать': 315,
#  'чуха::чуха': 316,
#  'перевясло': 317,
#  'игренька': 318,
#  'стремя': 319,
#  'выбоинка': 320,
#  'вейцик': 321,
#  'зад': 322,
#  'поскальзываться': 323,
#  'опухать': 324,
#  'цирло': 325,
#  'неразгибаться': 326,
#  'миндалик': 327,
#  'отряхаться': 328,
#  'пошаркать': 329,
#  'вскакивать': 330,
#  'закорчиться': 331,
#  'тимчук': 332,
#  'поручиковый': 333,
#  'загарцевать': 334,
#  'топотня': 335,
#  'тротуарный::тумба': 336,
#  'загипсовать': 337,
#  'деревяшка': 338,
#  'проволочься': 339,
#  'заголяться': 340,
#  'очухиваться': 341,
#  'чулок': 342,
#  'скрючиваться': 343,
#  'хряснять': 344,
#  'подтопывать': 345,
#  'наземь': 346,
#  'приподниматься': 347,
#  'доваливаться': 348,
#  'юниф': 349,
#  'икроножный::мышца': 350,
#  'хрясь': 3810,
#  'упрыгивать': 352,
#  'чувяк': 353,
#  'полубосой': 354,
#  'жилейка': 355,
#  'киргизенки': 356,
#  'сползать': 357,
#  'культя': 358,
#  'мамэ': 359,
#  'храпок': 360,
#  'бухой': 361,
#  'нераздетый': 362,
#  'подсекаться': 363,
#  'выпрастывать': 364,
#  'валенок': 365,
#  'присовывать': 366,
#  'занеметь': 367,
#  'присед': 368,
#  'обшмыгивать': 369,
#  'полайтис': 370,
#  'пол': 6153,
#  'перекувыркнуться': 372,
#  'соскакивать': 373,
#  'карюшка': 374,
#  'оступаться': 375,
#  'латугино': 376,
#  'подножка': 377,
#  'пыжикова': 378,
#  'сапнуть': 379,
#  'чембур': 380,
#  'враскорячку': 381,
#  'прометнуться': 382,
#  'четырехпалый': 383,
#  'переваливаться': 384,
#  'кверху': 385,
#  'матюхинец': 386,
#  'мослатый': 387,
#  'валиться': 388,
#  'носочек': 389,
#  'ягодица': 390,
#  'кошеница': 391,
#  'топать': 392,
#  'супинатор': 393,
#  'коленко': 394,
#  'изнуренно': 395,
#  'заколевать': 396,
#  'обхлестывать': 397,
#  'скоробиться': 398,
#  'голеностоп': 399,
#  'изможденно': 400,
#  'рубашоночка': 401,
#  'сгорбиться': 402,
#  'охлестнуть': 403,
#  'спружинить': 404,
#  'челюсть': 405,
#  'засучивать': 406,
#  'прохромать': 407,
#  'пономарик': 408,
#  'босиком::прошлепать': 409,
#  'обхватывать': 410,
#  'задок': 411,
#  'хамкнуть': 412,
#  'полулысый': 413,
#  'жужик': 414,
#  'неметь': 415,
#  'мокрый': 416,
#  'копытце': 417,
#  'сенкич': 418,
#  'уцепиться': 419,
#  'аксюшка': 420,
#  'путлище': 421,
#  'беспоясый': 422,
#  'избочиться': 423,
#  'напотеть': 424,
#  'стаскивать': 425,
#  'перекладина': 426,
#  'приступка': 427,
#  'шлепать': 428,
#  'отслонять': 429,
#  'голенище': 430,
#  'матросский::тельняшка': 431,
#  'хлюп': 1750,
#  'юбка': 433,
#  'избочениться': 434,
#  'прохрустеть': 435,
#  'пристук': 436,
#  'непробривать': 437,
#  'спрыгивать': 438,
#  'подпарывать': 439,
#  'взнывать': 440,
#  'перемерзлый': 441,
#  'августич': 442,
#  'стешин': 443,
#  'вбок': 444,
#  'рябчиха': 445,
#  'кутерма': 446,
#  'брякнуться': 447,
#  'парализованно': 448,
#  'морщеный': 449,
#  'обтаптывать': 450,
#  'брехло': 451,
#  'обшлепывать': 452,
#  'бодрик': 453,
#  'костлявый': 454,
#  'кокорье': 455,
#  'окровавленный': 456,
#  'натруживать': 457,
#  'негнущийся': 458,
#  'пружиниться': 459,
#  'посбрасывать': 460,
#  'похныкивать': 461,
#  'вцепляться': 462,
#  'незавязнуть': 463,
#  'прапорщик::обаб': 464,
#  'затормошиться': 465,
#  'эскалор': 466,
#  'ховрах': 467,
#  'калям': 468,
#  'отпыхиваться': 469,
#  'оттяг': 470,
#  'наотлет': 471,
#  'задница': 472,
#  'упереться': 473,
#  'дрягать': 474,
#  'швырк': 475,
#  'сымить': 476,
#  'зубища': 477,
#  'отмерзать': 478,
#  'ушагать': 479,
#  'отклячивать': 480,
#  'томаз::гелашвили': 481,
#  'стонай': 482,
#  'глубой': 483,
#  'вздергиваться': 484,
#  'запрокидываться': 485,
#  'полусапог': 486,
#  'отяжелеть': 487,
#  'остол': 488,
#  'девчонкин': 489,
#  'нацеловывать': 490,
#  'вертануться': 491,
#  'подрыгивать': 492,
#  'рядовка': 493,
#  'втугую': 494,
#  'схватиться': 495,
#  'подкандальник': 496,
#  'сарафанишко': 497,
#  'мускулистый': 498,
#  'горбато': 499,
#  'балерун': 500,
#  'хвостать': 501,
#  'пристанывать': 502,
#  'сандалик': 503,
#  'чумбур': 504,
#  'мизинец': 505,
#  'закататься': 506,
#  'бамбуковый::тросточка': 507,
#  'замолачивать': 508,
#  'костылик': 509,
#  'чинников': 510,
#  'подмышка': 511,
#  'топнуть': 512,
#  'прыгать': 513,
#  'пружинистый': 514,
#  'расшнуровывать': 515,
#  'кривоплечий': 516,
#  'баладжан': 517,
#  'вихляй': 518,
#  'живулька': 519,
#  'хлебина': 520,
#  'стэк': 521,
#  'ботиночный': 522,
#  'распластываться': 523,
#  'ручища': 524,
#  'резонивать': 525,
#  'половица': 526,
#  'мокрохвостый': 527,
#  'хрупнуть': 528,
#  'подбородок': 529,
#  'отваливаться': 530,
#  'двойнятой': 531,
#  'железина': 532,
#  'телепаться': 533,
#  'припечек': 534,
#  'стеннов': 535,
#  'прыг::прыг': 536,
#  'цыпки': 537,
#  'захлипать': 538,
#  'хусейнов': 539,
#  'вцепиться': 540,
#  'салабонский': 541,
#  'соскальзывать': 542,
#  'оцарапаться': 543,
#  'петькин::мамка': 544,
#  'грабка': 545,
#  'тапочек': 546,
#  'гришаток': 547,
#  'изрезаться': 548,
#  'полурасстегнуть': 549,
#  'подколенный': 550,
#  'отвертеть': 551,
#  'животастый': 552,
#  'механикус': 553,
#  'выворачивать': 554,
#  'заплетать::косичка': 555,
#  'арматурин': 556,
#  'лаптишок': 557,
#  'скрипнуть::половица': 558,
#  'закривляться': 559,
#  'рраз': 560,
#  'чапка': 561,
#  'по-старчески': 562,
#  'напересечь': 563,
#  'репица': 564,
#  'поняга': 565,
#  'засаднить': 566,
#  'вадюхин': 567,
#  'лежмя': 568,
#  'подсучивать': 569,
#  'жененок': 570,
#  'ивчиков': 571,
#  'зачавкать': 572,
#  'затопотать': 573,
#  'вехтем': 574,
#  'трикони': 575,
#  'пропрыгать': 576,
#  'клавдя': 577,
#  'привздергивать': 578,
#  'роспуски': 579,
#  'принагибаться': 580,
#  'приотпускать': 581,
#  'гипсовать': 582,
#  'лыв': 583,
#  'норовисто': 584,
#  'сибилек': 585,
#  'телохран': 586,
#  'привставать': 587,
#  'распрямляться': 588,
#  'свешиваться': 589,
#  'ушибать': 590,
#  'ручонка': 591,
#  'заелозить': 592,
#  'вприскочку': 593,
#  'тысяченогий': 594,
#  'гамат': 595,
#  'качаться': 596,
#  'банановый::кожура': 597,
#  'грянуться': 598,
#  'брыкнуть': 599,
#  'забинтовывать': 600,
#  'трехвершковый': 601,
#  'гоп::гоп': 602,
#  'бияся': 603,
#  'притолк': 604,
#  'косье': 605,
#  'зацарапать': 606,
#  'пошевелиться': 607,
#  'диванный::валик': 608,
#  'чедыга': 609,
#  'правдей::федоровна': 610,
#  'брутик': 611,
#  'зиновье': 612,
#  'сутуло': 613,
#  'стопа': 614,
#  'покачиваться': 615,
#  'стремлев': 616,
#  'садабек': 617,
#  'баградзе': 618,
#  'счесывать': 619,
#  'крючить': 620,
#  'лопатка': 621,
#  'войлочек': 622,
#  'свесить': 623,
#  'кубарем': 624,
#  'прижимать': 625,
#  'размариваться': 626,
#  'шнуровать::ботинок': 627,
#  'хитянин': 628,
#  'ходилка': 629,
#  'голова': 630,
#  'босу': 631,
#  'припадать': 632,
#  'задик': 633,
#  'тш::ш': 634,
#  'дырища': 635,
#  'сайпудин': 636,
#  'зюнька': 637,
#  'заколесить': 638,
#  'толстошеий': 639,
#  'криветь': 640,
#  'зазеленить': 641,
#  'скидывать': 642,
#  'напрыгивать': 643,
#  'митрыч': 644,
#  'джагд': 645,
#  'докуривать::цигарка': 646,
#  'наваляться': 647,
#  'доковылять': 648,
#  'эвдокия': 649,
#  'штаны': 650,
#  'дырк': 651,
#  'одеревенеть': 652,
#  'шебуршать': 653,
#  'затопать': 654,
#  'держак': 655,
#  'пола': 656,
#  'станушка': 657,
#  'задеревенеть': 658,
#  'сшибать': 659,
#  'вислогубый': 660,
#  'няньчук': 661,
#  'засупонивать': 662,
#  'никола::зяблов': 663,
#  'плюхнуться': 664,
#  'обмызгивать': 665,
#  'уросливый': 666,
#  'вдеваться': 667,
#  'обмерзлый': 668,
#  'переминаться': 669,
#  'ревнуть': 670,
#  'подмогнь': 671,
#  'вельм': 672,
#  'шоферка': 673,
#  'испачкать': 674,
#  'чирик': 1796,
#  'разнашивать': 676,
#  'ботфорт': 677,
#  'завлажнеть': 678,
#  'башмачок': 679,
#  'хлюпкий': 680,
#  'прыгнуть': 681,
#  'коровий::лепеха': 682,
#  'налыгач': 683,
#  'пропотелый': 684,
#  'трястись': 685,
#  'вскрикивать': 686,
#  'бэтээре': 687,
#  'предплечье': 688,
#  'лутошка': 689,
#  'хведько': 690,
#  'скрябок': 691,
#  'корточки': 692,
#  'кися::ляля': 693,
#  'обезножеть': 694,
#  'маваш::гери': 695,
#  'пинать': 696,
#  'опрокидываться::навзничь': 697,
#  'корноухий': 698,
#  'неловко': 699,
#  'наклоняться': 700,
#  'смоляной::светоч': 701,
#  'пригибаться': 702,
#  'слегонец': 703,
#  'отскочить': 704,
#  'чунцюань': 705,
#  'балалай': 706,
#  'балахонистый': 707,
#  'ранешное': 708,
#  'заспанно': 709,
#  'сгорбатиться': 710,
#  'топотание': 711,
#  'оскаль': 712,
#  'неподвижно': 713,
#  'нумердышев': 714,
#  'chulos': 715,
#  'заледенить': 716,
#  'вспузыриваться': 717,
#  'по-девчоночьи': 718,
#  'водосточный::желоб': 719,
#  'захлюпать': 720,
#  'дергаться': 721,
#  'мокроватый': 722,
#  'натуженно': 723,
#  'лидкин': 724,
#  'полуспущенный': 725,
#  'торс': 726,
#  'поджимать': 727,
#  'армячишко': 728,
#  'охлюпка': 729,
#  'спичечка': 730,
#  'упятиться': 731,
#  'зипунишко': 732,
#  'деревяго': 733,
#  'разминать::затекший': 734,
#  'бледноволосый': 735,
#  'заплечье': 736,
#  'захромать': 737,
#  'степкина': 738,
#  'хлюпнуть': 739,
#  'якэлене': 740,
#  'сенокосец': 741,
#  'веревочный::постромка': 742,
#  'впереверт': 743,
#  'хлипко': 744,
#  'коленный::сустав': 745,
#  'подклад': 746,
#  'итка': 747,
#  'покачнуться': 748,
#  'кривошея': 749,
#  'непроворный': 750,
#  'по-калмыцки': 751,
#  'петюкевич': 752,
#  'сморщиться': 753,
#  'раскачнуться': 754,
#  'охапочка': 755,
#  'колывушка': 756,
#  'костоправка': 757,
#  'судорожно': 758,
#  'торчмя': 759,
#  'забрызгать': 760,
#  'взмыливаться': 761,
#  'буранкин': 762,
#  'френчик': 763,
#  'заковылять': 764,
#  'сутулить': 765,
#  'краек': 766,
#  'верунька': 767,
#  'намаять': 768,
#  'шалнер': 769,
#  'спереди': 5062,
#  'витвемахер': 771,
#  'муренок': 772,
#  'заслеживать': 773,
#  'изгибаться': 774,
#  'гмыкать': 775,
#  'степлиться': 776,
#  'щепье': 777,
#  'сомье': 778,
#  'поелозить': 779,
#  'пришаркивать': 780,
#  'волоковой::оконце': 781,
#  'нековывать': 782,
#  'ляскнуть': 783,
#  'надрубать': 784,
#  'пьфа': 785,
#  'ляшок': 786,
#  'кособоко': 787,
#  'криволапый': 788,
#  'запыхиваться': 789,
#  'екать::селезенка': 790,
#  'сзади': 964,
#  'набок': 792,
#  'кровенеть': 793,
#  'по-поросячьи': 794,
#  'стерлядник': 795,
#  'перебинтовывать': 796,
#  'узловатый': 797,
#  'шаркание': 798,
#  'отдышиваться': 799,
#  'кошовка': 800,
#  'сбороть': 801,
#  'бесслезный::рыдание': 802,
#  'латып': 803,
#  'надя::лузина': 804,
#  'отпрукивать': 805,
#  'взвизгивать': 806,
#  'цоб::цобе': 807,
#  'зябко::поеживаться': 808,
#  'святов': 809,
#  'упираться': 810,
#  'двухлопастный::весло': 811,
#  'верезжать': 812,
#  'сочиться::сукровица': 813,
#  'раскачиваться': 814,
#  'семиглаз': 815,
#  'вжик::вжик': 816,
#  'хрустко': 817,
#  'бочажина': 818,
#  'подгубщик': 819,
#  'жилистый': 820,
#  'стул': 821,
#  'лучезапястный::сустав': 822,
#  'закоченеть': 823,
#  'попинать': 824,
#  'разминать': 825,
#  'излупить': 826,
#  'сухоногий': 827,
#  'поспелко': 828,
#  'угорышек': 829,
#  'кособочиться': 830,
#  'размахать': 831,
#  'дегтярок': 832,
#  'сваливаться': 833,
#  'мальчугашка': 834,
#  'клетчатый::плед': 835,
#  'спинища': 836,
#  'хивук': 837,
#  'валином': 838,
#  'неподкованный': 839,
#  'умащиваться': 840,
#  'икроножный': 841,
#  'фичас': 842,
#  'ошметие': 843,
#  'упруго': 844,
#  'курзов': 845,
#  'взмахивать': 846,
#  'ведерный::бутыль': 847,
#  'лолла': 848,
#  'окоченевать': 849,
#  'шлепнуться': 850,
#  'запястье': 851,
#  'мараленок': 852,
#  'маляев': 853,
#  'колотовкинский': 854,
#  'поморщиваться': 855,
#  'пораниться': 856,
#  'напяливаться': 857,
#  'чесанок': 858,
#  'отхаркнуть': 859,
#  'кирька': 860,
#  'рассучивать': 861,
#  'выгибать': 862,
#  'сюзик': 863,
#  'диноцефал': 864,
#  'вскидывать': 865,
#  'ортюха': 866,
#  'припечка': 867,
#  'фульбо': 868,
#  'мосластый': 869,
#  'захоркать': 870,
#  'митенька::малышня': 871,
#  'лизкин': 872,
#  'копельбаум': 873,
#  'мочалистый': 874,
#  'корнилка': 875,
#  'накладь': 876,
#  'подскальзываться': 877,
#  'крылечный': 878,
#  'волчишко': 879,
#  'ключица': 880,
#  'дон::рипатый': 881,
#  'лапнуть': 882,
#  'табуретка': 883,
#  'вниз': 884,
#  'вперевалочку': 885,
#  'ослабленно': 886,
#  'андзор': 887,
#  'натуживать': 888,
#  'пошевелить': 889,
#  'поза::ромберг': 890,
#  'ручьевина': 891,
#  'жаждущий': 892,
#  'откачнуть': 893,
#  'вдергивать': 894,
#  'прогибаться': 895,
#  'придавливать': 896,
#  'раскорячиваться': 897,
#  'паравян': 898,
#  'курмаяров': 899,
#  'михеевский': 900,
#  'пошвыривать': 901,
#  'ившая': 902,
#  'длиннущий': 903,
#  'позвоночник': 904,
#  'тальярь': 905,
#  'викеша': 906,
#  'собаченок': 907,
#  'нетвердо': 908,
#  'подшивать::валенок': 909,
#  'саломыга': 910,
#  'гриха': 911,
#  'савостьян::максимыч': 912,
#  'пиллерс': 913,
#  'кверх': 914,
#  'уминаться': 915,
#  'недочищать': 916,
#  'филимошка': 917,
#  'лысоголовый': 918,
#  'бухнуться': 919,
#  'соступать': 920,
#  'волосатый': 921,
#  'ступенька': 922,
#  'балалаечный::струна': 923,
#  'пудовый::гиря': 924,
#  'табурет': 925,
#  'сапожонка': 926,
#  'взрыдывать': 927,
#  'топотать': 928,
#  'анчик': 929,
#  'колевать': 930,
#  'локтевой::сгиб': 931,
#  'переступать': 932,
#  'митродор': 933,
#  'позвякивать::бубенцы': 934,
#  'даум': 935,
#  'паралик': 936,
#  'тютиков': 937,
#  'волтузить': 938,
#  'догладывать': 939,
#  'смерзать': 940,
#  'атаманова': 941,
#  'кроссовка': 942,
#  'лансада': 943,
#  'кусануть': 944,
#  'пумперпикель': 945,
#  'проплестись': 946,
#  'гакать': 947,
#  'башмачонка': 948,
#  'дышловой': 949,
#  'носишко': 950,
#  'лядвей': 951,
#  'завихлять': 952,
#  'жора::козакевич': 953,
#  'запрокидывать': 954,
#  'истаптывать': 955,
#  'дожжик': 956,
#  'ощупываться': 957,
#  'гавкин': 958,
#  'полузадохшийся': 959,
#  'зашлепать': 960,
#  'хрясть': 961,
#  'стремечко': 962,
#  'митрять': 963,
#  'ссутулить': 965,
#  'приплясывать': 966,
#  'еникеева': 967,
#  'дулемберг': 968,
#  'танкистский::шлем': 969,
#  'голый': 970,
#  'карябать': 971,
#  'по-ямщицки': 972,
#  'закоченелый': 973,
#  'калошки': 974,
#  'покусывать::травинка': 975,
#  'гальчевский': 976,
#  'губище': 977,
#  'кладочка': 978,
#  'угу::промычать': 979,
#  'отшвыривать': 980,
#  'трык::трык': 981,
#  'жюль::мартэна': 982,
#  'по-молдавански': 983,
#  'нерасчесывать': 984,
#  'приминаться': 985,
#  'пришлепать': 986,
#  'экронец': 987,
#  'похрамывать': 988,
#  'щека': 989,
#  'зазябнуть': 990,
#  'приношенный': 991,
#  'каряев': 992,
#  'гнуться': 993,
#  'упасть': 994,
#  'стукнуться': 995,
#  'постель': 996,
#  'лужа': 997,
#  'посеменить': 998,
#  'насухой': 999,
#  'лапоть': 1001,
#  'ломайл': 1002,
#  'извозиться': 1003,
#  ...}
